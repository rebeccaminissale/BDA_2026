# %%
# Import the pandas library (the main tool for working with tabular data in Python)
import pandas as pd

# Load all data from the CSV file into a DataFrame
df = pd.read_csv('data/symbol_info_3-25.csv')

# Randomly pick 25 rows from the full dataset
# random_state=42 ensures we always get the same 25 rows (for reproducibility)
df_sample = df.sample(25, random_state=122)

# Keep only the 4 columns we need
df_sample = df_sample[['symbol', 'market_cap', 'sector', 'fifty_two_week_high']]

# Display the result
print('--- Initial Sampled DataFrame ---')
print(df_sample)
# Out:
# --- Initial Sampled DataFrame ---
#     symbol    market_cap                  sector  fifty_two_week_high
# 389     IP   27511121920       Consumer Cyclical            60.360001
# 105   MELI  106224738304       Consumer Cyclical          2374.540039
# 903    DBX    7741259776              Technology            33.330002
# 818   FYBR    8976740352  Communication Services            39.209999
# 190    EMR   63782731776             Industrials           134.850006
# 863   CBSH    8237515264      Financial Services            72.752380
# 792    STN    9535938560             Industrials            90.239998
# 343    CAH   32147922944              Healthcare           133.669998
# 620   ITCI   14023620608              Healthcare           131.669998
# 913   EXLS    7534188544              Technology            52.430000
# 339    STZ   32333729792      Consumer Defensive           274.869995
# 479   TROW   20713900032      Financial Services           125.809998
# 294   LULU   39512559616       Consumer Cyclical           423.320007
# 146   SCCO   79944736768         Basic Materials           128.374039
# 497   NTNX   19476992000              Technology            79.989998
# 403    PPL   25825529856               Utilities            35.910000
# 108   ANET  104836898816              Technology           133.574997
# 980    TFX    6563641856              Healthcare           249.910004
# 916     FR    7477808128             Real Estate            58.169998
# 333     IR   32919791616             Industrials           106.029999
# 701    RDY   11451099136              Healthcare            16.892000
# 301   HOOD   38659207168      Financial Services            66.910004
# 466    TSN   21521238016      Consumer Defensive            66.879997
# 896    NNN    7825935360             Real Estate            49.570000
# 651    SYM   12732991488             Industrials            50.404999
